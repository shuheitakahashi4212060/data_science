# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = './drive/MyDrive/pandas-dataset/sales_transactions.xlsx'

# %%
df = pd.read_excel(file_path, index_col=0)

# %%
df
# Out:
#            ymd       transaction_id  SKU  transaction_type  payment  details  \
# 0   2020-01-07  250-0042069-0262213   60                 0        1        4
# 1   2020-01-07  250-0042069-0262213   60                 0        1        8
# 2   2020-01-07  250-0042069-0262213   60                 0        1       10
# 3   2020-01-07  250-0042069-0262213   60                 0        4        0
# 4   2020-01-07  250-0042069-0262213   60                 0        2        2
# ..         ...                  ...  ...               ...      ...      ...
# 609 2019-11-20  503-0100465-6209437    2                 0        3       14
# 610 2019-11-20  503-0100465-6209437    2                 0        4        0
# 611 2019-11-20  503-0100465-6209437    2                 0        2        9
# 612 2019-11-20  503-0100465-6209437    2                 0        2       12
# 613 2019-11-20  503-0100465-6209437    2                 0        2       14
#
#      revenue  quantity  product_name
# 0       -314       NaN            21
# 1       -499       NaN            21
# 2       -693       NaN            21
# 3       5727       1.0            21
# 4         29       NaN            21
# ..       ...       ...           ...
# 609     -373       NaN            60
# 610      682       1.0            60
# 611       68       NaN            60
# 612       37       NaN            60
# 613      373       NaN            60
#
# [597 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 597 entries, 0 to 613
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ymd               597 non-null    datetime64[ns]
#  1   transaction_id    597 non-null    object
#  2   SKU               597 non-null    int64
#  3   transaction_type  597 non-null    int64
#  4   payment           597 non-null    int64
#  5   details           597 non-null    int64
#  6   revenue           597 non-null    int64
#  7   quantity          144 non-null    float64
#  8   product_name      597 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(6), object(1)
# memory usage: 46.6+ KB

# %%
df['ymd'] = df['ymd'].astype(str)

# %%
df.dtypes
# Out:
# ymd                  object
# transaction_id       object
# SKU                   int64
# transaction_type      int64
# payment               int64
# details               int64
# revenue               int64
# quantity            float64
# product_name          int64
# dtype: object

# %%
df['ymd'] = pd.to_datetime(df['ymd'])

# %%
df.dtypes
# Out:
# ymd                 datetime64[ns]
# transaction_id              object
# SKU                          int64
# transaction_type             int64
# payment                      int64
# details                      int64
# revenue                      int64
# quantity                   float64
# product_name                 int64
# dtype: object

# %%
df['ymd'].dt.year
# Out:
# 0      2020
# 1      2020
# 2      2020
# 3      2020
# 4      2020
#        ...
# 609    2019
# 610    2019
# 611    2019
# 612    2019
# 613    2019
# Name: ymd, Length: 597, dtype: int64

# %%
df
# Out:
#            ymd       transaction_id  SKU  transaction_type  payment  details  \
# 0   2020-01-07  250-0042069-0262213   60                 0        1        4
# 1   2020-01-07  250-0042069-0262213   60                 0        1        8
# 2   2020-01-07  250-0042069-0262213   60                 0        1       10
# 3   2020-01-07  250-0042069-0262213   60                 0        4        0
# 4   2020-01-07  250-0042069-0262213   60                 0        2        2
# ..         ...                  ...  ...               ...      ...      ...
# 609 2019-11-20  503-0100465-6209437    2                 0        3       14
# 610 2019-11-20  503-0100465-6209437    2                 0        4        0
# 611 2019-11-20  503-0100465-6209437    2                 0        2        9
# 612 2019-11-20  503-0100465-6209437    2                 0        2       12
# 613 2019-11-20  503-0100465-6209437    2                 0        2       14
#
#      revenue  quantity  product_name
# 0       -314       NaN            21
# 1       -499       NaN            21
# 2       -693       NaN            21
# 3       5727       1.0            21
# 4         29       NaN            21
# ..       ...       ...           ...
# 609     -373       NaN            60
# 610      682       1.0            60
# 611       68       NaN            60
# 612       37       NaN            60
# 613      373       NaN            60
#
# [597 rows x 9 columns]

# %%
df['ymd'].dt.month
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 609    11
# 610    11
# 611    11
# 612    11
# 613    11
# Name: ymd, Length: 597, dtype: int64

# %%
df['ymd'].dt.day
# Out:
# 0       7
# 1       7
# 2       7
# 3       7
# 4       7
#        ..
# 609    20
# 610    20
# 611    20
# 612    20
# 613    20
# Name: ymd, Length: 597, dtype: int64

# %%
df
# Out:
#            ymd       transaction_id  SKU  transaction_type  payment  details  \
# 0   2020-01-07  250-0042069-0262213   60                 0        1        4
# 1   2020-01-07  250-0042069-0262213   60                 0        1        8
# 2   2020-01-07  250-0042069-0262213   60                 0        1       10
# 3   2020-01-07  250-0042069-0262213   60                 0        4        0
# 4   2020-01-07  250-0042069-0262213   60                 0        2        2
# ..         ...                  ...  ...               ...      ...      ...
# 609 2019-11-20  503-0100465-6209437    2                 0        3       14
# 610 2019-11-20  503-0100465-6209437    2                 0        4        0
# 611 2019-11-20  503-0100465-6209437    2                 0        2        9
# 612 2019-11-20  503-0100465-6209437    2                 0        2       12
# 613 2019-11-20  503-0100465-6209437    2                 0        2       14
#
#      revenue  quantity  product_name
# 0       -314       NaN            21
# 1       -499       NaN            21
# 2       -693       NaN            21
# 3       5727       1.0            21
# 4         29       NaN            21
# ..       ...       ...           ...
# 609     -373       NaN            60
# 610      682       1.0            60
# 611       68       NaN            60
# 612       37       NaN            60
# 613      373       NaN            60
#
# [597 rows x 9 columns]

# %%
df = df.fillna({'quantity': 1})

# %%
df
# Out:
#            ymd       transaction_id  SKU  transaction_type  payment  details  \
# 0   2020-01-07  250-0042069-0262213   60                 0        1        4
# 1   2020-01-07  250-0042069-0262213   60                 0        1        8
# 2   2020-01-07  250-0042069-0262213   60                 0        1       10
# 3   2020-01-07  250-0042069-0262213   60                 0        4        0
# 4   2020-01-07  250-0042069-0262213   60                 0        2        2
# ..         ...                  ...  ...               ...      ...      ...
# 609 2019-11-20  503-0100465-6209437    2                 0        3       14
# 610 2019-11-20  503-0100465-6209437    2                 0        4        0
# 611 2019-11-20  503-0100465-6209437    2                 0        2        9
# 612 2019-11-20  503-0100465-6209437    2                 0        2       12
# 613 2019-11-20  503-0100465-6209437    2                 0        2       14
#
#      revenue  quantity  product_name
# 0       -314       1.0            21
# 1       -499       1.0            21
# 2       -693       1.0            21
# 3       5727       1.0            21
# 4         29       1.0            21
# ..       ...       ...           ...
# 609     -373       1.0            60
# 610      682       1.0            60
# 611       68       1.0            60
# 612       37       1.0            60
# 613      373       1.0            60
#
# [597 rows x 9 columns]

# %%
df['sales'] = df['revenue'] * df['quantity']

# %%
df
# Out:
#            ymd       transaction_id  SKU  transaction_type  payment  details  \
# 0   2020-01-07  250-0042069-0262213   60                 0        1        4
# 1   2020-01-07  250-0042069-0262213   60                 0        1        8
# 2   2020-01-07  250-0042069-0262213   60                 0        1       10
# 3   2020-01-07  250-0042069-0262213   60                 0        4        0
# 4   2020-01-07  250-0042069-0262213   60                 0        2        2
# ..         ...                  ...  ...               ...      ...      ...
# 609 2019-11-20  503-0100465-6209437    2                 0        3       14
# 610 2019-11-20  503-0100465-6209437    2                 0        4        0
# 611 2019-11-20  503-0100465-6209437    2                 0        2        9
# 612 2019-11-20  503-0100465-6209437    2                 0        2       12
# 613 2019-11-20  503-0100465-6209437    2                 0        2       14
#
#      revenue  quantity  product_name   sales
# 0       -314       1.0            21  -314.0
# 1       -499       1.0            21  -499.0
# 2       -693       1.0            21  -693.0
# 3       5727       1.0            21  5727.0
# 4         29       1.0            21    29.0
# ..       ...       ...           ...     ...
# 609     -373       1.0            60  -373.0
# 610      682       1.0            60   682.0
# 611       68       1.0            60    68.0
# 612       37       1.0            60    37.0
# 613      373       1.0            60   373.0
#
# [597 rows x 10 columns]

# %%
daily_sales_df = df.groupby('ymd')['sales'].sum().reset_index()

# %%
daily_sales_df
# Out:
#           ymd    sales
# 0  2019-11-20   3128.0
# 1  2019-11-21   2516.0
# 2  2019-11-23    928.0
# 3  2019-11-24   1491.0
# 4  2019-11-26   1095.0
# 5  2019-11-28   1555.0
# 6  2019-11-30   1105.0
# 7  2019-12-03   6661.0
# 8  2019-12-07   6525.0
# 9  2019-12-09    302.0
# 10 2019-12-11   5772.0
# 11 2019-12-12  11462.0
# 12 2019-12-13  28638.0
# 13 2019-12-14  15581.0
# 14 2019-12-15   8176.0
# 15 2019-12-16  29219.0
# 16 2019-12-18   7763.0
# 17 2019-12-19  18175.0
# 18 2019-12-20  75777.0
# 19 2019-12-21  25522.0
# 20 2019-12-22   7517.0
# 21 2019-12-23   7685.0
# 22 2019-12-24  22415.0
# 23 2019-12-25   8685.0
# 24 2019-12-26  27369.0
# 25 2019-12-27   5416.0
# 26 2019-12-28  31863.0
# 27 2019-12-29   -858.0
# 28 2019-12-30   6954.0
# 29 2019-12-31   9197.0
# 30 2020-01-02   3690.0
# 31 2020-01-03  14864.0
# 32 2020-01-04  15100.0
# 33 2020-01-05  11326.0
# 34 2020-01-06  22666.0
# 35 2020-01-07   5108.0

# %%
plt.plot(daily_sales_df['ymd'],daily_sales_df['sales'])
plt.xticks(rotation=90)
# Out:
# (array([737385., 737394., 737401., 737408., 737415., 737425., 737432.]),
#  <a list of 7 Text major ticklabel objects>)

# %%
daily_sales_df.head()
# Out:
#          ymd   sales
# 0 2019-11-20  3128.0
# 1 2019-11-21  2516.0
# 2 2019-11-23   928.0
# 3 2019-11-24  1491.0
# 4 2019-11-26  1095.0

# %%
daily_sales_df.set_index('ymd').resample('W').sum()
# Out:
#                sales
# ymd
# 2019-11-24    8063.0
# 2019-12-01    3755.0
# 2019-12-08   13186.0
# 2019-12-15   69931.0
# 2019-12-22  163973.0
# 2019-12-29  102575.0
# 2020-01-05   61131.0
# 2020-01-12   27774.0

# %%
daily_sales_df.head(10)
# Out:
#          ymd   sales
# 0 2019-11-20  3128.0
# 1 2019-11-21  2516.0
# 2 2019-11-23   928.0
# 3 2019-11-24  1491.0
# 4 2019-11-26  1095.0
# 5 2019-11-28  1555.0
# 6 2019-11-30  1105.0
# 7 2019-12-03  6661.0
# 8 2019-12-07  6525.0
# 9 2019-12-09   302.0

# %%
daily_sales_df['ymd'] - daily_sales_df.iloc[0,0]
# Out:
# 0     0 days
# 1     1 days
# 2     3 days
# 3     4 days
# 4     6 days
# 5     8 days
# 6    10 days
# 7    13 days
# 8    17 days
# 9    19 days
# 10   21 days
# 11   22 days
# 12   23 days
# 13   24 days
# 14   25 days
# 15   26 days
# 16   28 days
# 17   29 days
# 18   30 days
# 19   31 days
# 20   32 days
# 21   33 days
# 22   34 days
# 23   35 days
# 24   36 days
# 25   37 days
# 26   38 days
# 27   39 days
# 28   40 days
# 29   41 days
# 30   43 days
# 31   44 days
# 32   45 days
# 33   46 days
# 34   47 days
# 35   48 days
# Name: ymd, dtype: timedelta64[ns]
