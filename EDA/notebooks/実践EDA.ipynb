# %%
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px

# %%
file_path = './drive/MyDrive/pandas-dataset/citibike_trips_2017_sampled.csv'

# %%
df = pd.read_csv(file_path, sep=',')

# %%
df.head()
# Out:
#    Unnamed: 0  tripduration        starttime         stoptime  \
# 0           0          1877   2017/4/3 16:51   2017/4/3 17:22
# 1           1           314   2017/4/11 8:26   2017/4/11 8:31
# 2           2          2686  2017/4/15 16:12  2017/4/15 16:56
# 3           3          1494  2017/7/10 15:28  2017/7/10 15:53
# 4           4           606  2017/8/22 10:13  2017/8/22 10:23
#
#    start_station_id  start_station_name  start_station_latitude  \
# 0               498  Broadway & W 32 St               40.748549
# 1               533  Broadway & W 39 St               40.752996
# 2               430    York St & Jay St               40.701485
# 3              3474   6 Ave & Spring St               40.725256
# 4               432   E 7 St & Avenue A               40.726218
#
#    start_station_longitude  end_station_id         end_station_name  \
# 0               -73.988084             382  University Pl & E 14 St
# 1               -73.987216             402       Broadway & E 22 St
# 2               -73.986569            3125            45 Rd & 11 St
# 3               -74.004121             480         W 53 St & 10 Ave
# 4               -73.983799             438      St Marks Pl & 1 Ave
#
#    end_station_latitude  end_station_longitude  bikeid    usertype  \
# 0             40.734927             -73.992005   27181    Customer
# 1             40.740343             -73.989551   26081  Subscriber
# 2             40.747086             -73.949772   28244  Subscriber
# 3             40.766697             -73.990617   28398  Subscriber
# 4             40.727791             -73.985649   27444  Subscriber
#
#    birth_year   gender  customer_plan dayofweek   age
# 0         NaN  unknown            NaN       Mon   NaN
# 1      1992.0     male            NaN       Tue  25.0
# 2      1994.0     male            NaN       Sat  25.0
# 3      1971.0     male            NaN       Mon  45.0
# 4      1990.0   female            NaN       Tue  25.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141562 entries, 0 to 141561
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Unnamed: 0               141562 non-null  int64
#  1   tripduration             141562 non-null  int64
#  2   starttime                141562 non-null  object
#  3   stoptime                 141562 non-null  object
#  4   start_station_id         141562 non-null  int64
#  5   start_station_name       141562 non-null  object
#  6   start_station_latitude   141562 non-null  float64
#  7   start_station_longitude  141562 non-null  float64
#  8   end_station_id           141562 non-null  int64
#  9   end_station_name         141562 non-null  object
#  10  end_station_latitude     141562 non-null  float64
#  11  end_station_longitude    141562 non-null  float64
#  12  bikeid                   141562 non-null  int64
#  13  usertype                 141562 non-null  object
#  14  birth_year               126281 non-null  float64
#  15  gender                   141562 non-null  object
#  16  customer_plan            0 non-null       float64
#  17  dayofweek                141562 non-null  object
#  18  age                      126281 non-null  float64
# dtypes: float64(7), int64(5), object(7)
# memory usage: 20.5+ MB

# %%
df['starttime'] = pd.to_datetime(df['starttime'])
df['stoptime'] = pd.to_datetime(df['stoptime'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141562 entries, 0 to 141561
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Unnamed: 0               141562 non-null  int64
#  1   tripduration             141562 non-null  int64
#  2   starttime                141562 non-null  datetime64[ns]
#  3   stoptime                 141562 non-null  datetime64[ns]
#  4   start_station_id         141562 non-null  int64
#  5   start_station_name       141562 non-null  object
#  6   start_station_latitude   141562 non-null  float64
#  7   start_station_longitude  141562 non-null  float64
#  8   end_station_id           141562 non-null  int64
#  9   end_station_name         141562 non-null  object
#  10  end_station_latitude     141562 non-null  float64
#  11  end_station_longitude    141562 non-null  float64
#  12  bikeid                   141562 non-null  int64
#  13  usertype                 141562 non-null  object
#  14  birth_year               126281 non-null  float64
#  15  gender                   141562 non-null  object
#  16  customer_plan            0 non-null       float64
#  17  dayofweek                141562 non-null  object
#  18  age                      126281 non-null  float64
# dtypes: datetime64[ns](2), float64(7), int64(5), object(5)
# memory usage: 20.5+ MB

# %%
df['num_trips'] = 1

# %%
df['tripduration_min']  = df['tripduration'] / 60.0

# %%
df['month'] = df['starttime'].dt.month
df['day'] = df['starttime'].dt.day
df['date'] = df['starttime'].dt.date
df['hour'] = df['starttime'].dt.hour
df['day_of_week'] = df['starttime'].dt.dayofweek

# %%
df
# Out:
#         Unnamed: 0  tripduration           starttime            stoptime  \
# 0                0          1877 2017-04-03 16:51:00 2017-04-03 17:22:00
# 1                1           314 2017-04-11 08:26:00 2017-04-11 08:31:00
# 2                2          2686 2017-04-15 16:12:00 2017-04-15 16:56:00
# 3                3          1494 2017-07-10 15:28:00 2017-07-10 15:53:00
# 4                4           606 2017-08-22 10:13:00 2017-08-22 10:23:00
# ...            ...           ...                 ...                 ...
# 141557      141557          1488 2017-07-17 21:38:00 2017-07-17 22:03:00
# 141558      141558           217 2017-05-18 16:35:00 2017-05-18 16:39:00
# 141559      141559          1138 2017-07-06 06:47:00 2017-07-06 07:06:00
# 141560      141560           955 2017-05-17 08:13:00 2017-05-17 08:29:00
# 141561      141561          1434 2017-07-09 17:19:00 2017-07-09 17:42:00
#
#         start_station_id       start_station_name  start_station_latitude  \
# 0                    498       Broadway & W 32 St               40.748549
# 1                    533       Broadway & W 39 St               40.752996
# 2                    430         York St & Jay St               40.701485
# 3                   3474        6 Ave & Spring St               40.725256
# 4                    432        E 7 St & Avenue A               40.726218
# ...                  ...                      ...                     ...
# 141557              3302  Columbus Ave & W 103 St               40.796935
# 141558               311   Norfolk St & Broome St               40.717227
# 141559              3236       W 42 St & Dyer Ave               40.758985
# 141560               284    Greenwich Ave & 8 Ave               40.739017
# 141561              3282          5 Ave & E 88 St               40.783070
#
#         start_station_longitude  end_station_id          end_station_name  \
# 0                    -73.988084             382   University Pl & E 14 St
# 1                    -73.987216             402        Broadway & E 22 St
# 2                    -73.986569            3125             45 Rd & 11 St
# 3                    -74.004121             480          W 53 St & 10 Ave
# 4                    -73.983799             438       St Marks Pl & 1 Ave
# ...                         ...             ...                       ...
# 141557               -73.964341            3302   Columbus Ave & W 103 St
# 141558               -73.988021             502       Henry St & Grand St
# 141559               -73.993800             444        Broadway & W 24 St
# 141560               -74.002638             327  Vesey Pl & River Terrace
# 141561               -73.959390            3295  Central Park W & W 96 St
#
#         ...  customer_plan  dayofweek   age num_trips  tripduration_min month  \
# 0       ...            NaN        Mon   NaN         1         31.283333     4
# 1       ...            NaN        Tue  25.0         1          5.233333     4
# 2       ...            NaN        Sat  25.0         1         44.766667     4
# 3       ...            NaN        Mon  45.0         1         24.900000     7
# 4       ...            NaN        Tue  25.0         1         10.100000     8
# ...     ...            ...        ...   ...       ...               ...   ...
# 141557  ...            NaN        Mon  25.0         1         24.800000     7
# 141558  ...            NaN        Thr  55.0         1          3.616667     5
# 141559  ...            NaN        Thr  40.0         1         18.966667     7
# 141560  ...            NaN        Wed  60.0         1         15.916667     5
# 141561  ...            NaN        Sun   NaN         1         23.900000     7
#
#         day        date  hour  day_of_week
# 0         3  2017-04-03    16            0
# 1        11  2017-04-11     8            1
# 2        15  2017-04-15    16            5
# 3        10  2017-07-10    15            0
# 4        22  2017-08-22    10            1
# ...     ...         ...   ...          ...
# 141557   17  2017-07-17    21            0
# 141558   18  2017-05-18    16            3
# 141559    6  2017-07-06     6            3
# 141560   17  2017-05-17     8            2
# 141561    9  2017-07-09    17            6
#
# [141562 rows x 26 columns]

# %%
num_trips_df = df.groupby('month')['num_trips'].count().reset_index()

# %%
num_trips_df
# Out:
#    month  num_trips
# 0      4      13264
# 1      5      15276
# 2      6      17406
# 3      7      17528
# 4      8      18073
# 5      9      18762
# 6     10      18881
# 7     11      13350
# 8     12       9022

# %%
px.line(num_trips_df, x='month', y='num_trips', markers=True,
        width=800, height=600)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="5018c14b-ce03-46b5-a713-f6da40723ce8" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5018c14b-ce03-46b5-a713-f6da40723ce8")) {                    Plotly.newPlot(                        "5018c14b-ce03-46b5-a713-f6da40723ce8",                        [{"hovertemplate":"month=%{x}<br>num_trips=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"","orientation":"v","showlegend":false,"x":[4,5,6,7,8,9,10,11,12],"xaxis":"x","y":[13264,15276,17406,17528,18073,18762,18881,13350,9022],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"color ...

# %%
station_df = df.groupby('start_station_id')['num_trips'].count().reset_index()

# %%
station_df
# Out:
#      start_station_id  num_trips
# 0                  72        335
# 1                  79        247
# 2                  82         79
# 3                  83        140
# 4                 116        329
# ..                ...        ...
# 767              3644          9
# 768              3646          1
# 769              3647          1
# 770              3648          5
# 771              3649          3
#
# [772 rows x 2 columns]

# %%
top10_stations = station_df.sort_values(by='num_trips', ascending=False).head(10)['start_station_id']

# %%
top10_stations
# Out:
# 268     519
# 187     426
# 249     497
# 167     402
# 194     435
# 448    3255
# 243     490
# 216     459
# 263     514
# 271     523
# Name: start_station_id, dtype: int64

# %%
num_trips_df = df.groupby(['start_station_id', 'day_of_week'])['num_trips'].count().reset_index()
query = 'start_station_id in @top10_stations'
px.line(num_trips_df.query(query), x='day_of_week', y='num_trips',
        color='start_station_id', width=800, height=600)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="6f9202f0-7def-44a8-9bb7-e1451fb9a17c" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6f9202f0-7def-44a8-9bb7-e1451fb9a17c")) {                    Plotly.newPlot(                        "6f9202f0-7def-44a8-9bb7-e1451fb9a17c",                        [{"hovertemplate":"start_station_id=402<br>day_of_week=%{x}<br>num_trips=%{y}<extra></extra>","legendgroup":"402","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"402","orientation":"v","showlegend":true,"x":[0,1,2,3,4,5,6],"xaxis":"x","y":[159,155,164,159,132,86,82],"yaxis":"y","type":"scatter"},{"hovertemplate":"start_station_id=426<br>day_of_week=%{x}<br>num_trips=%{y}<extra></extra>","legendgroup":"426","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"426","orientation":"v","showlegend":true,"x":[0,1,2,3,4,5,6],"xaxis":"x","y":[133,132,130,135,136,165,140],"yaxis":"y","type":"scatter"},{"hovertemplate":"start_station_id=435<br>day_of_week=%{x}<br>num_trips=%{y}<extra></extra>","legendgroup":"435","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"435","orientation":"v","showlegend":true,"x":[0,1,2,3,4,5,6],"xaxis":"x","y":[132,141,145,129,142,117,104],"yaxis":"y","type":"scatter"},{"hovertemplate":"start_station_id=459<br>day_of_week=%{x}<br>num_trips=%{y}<extra></extra>","legendgroup":"459","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"459","orientation":"v","showlegend":true,"x":[0,1,2,3,4,5,6],"xaxis":"x","y":[106,139,108,130,90,106,82],"yaxis":"y","type":"scatter"},{"hovertemplate":"start_station_id=490<br>day_of_week=%{x}<br>num_trips=%{y}<extra></extra>","legendgroup":"490","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"490","orientation":"v","showlegend":true,"x":[0,1,2,3,4,5,6],"xaxis":"x","y":[102,134,151,132,150,66,72],"yaxis":"y","type":"scatter"},{"hovertemplate":"start_station_id=497<br>day_of_week=%{x}<br>num_trips=%{y}<extra></extra>","legendgroup":"497","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"497","orientation":"v","showlegend":true,"x":[0,1,2,3,4,5,6],"xaxis":"x","y":[129,124,152,174,131,135,114],"yaxis":"y","type":"scatter"},{"hovertemplate":"start_station_id=514<br>day_of_week=%{x}<br>num_trips=%{y}<extra></extra>","legendgroup":"514","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"514","orientation":"v","showlegend":true,"x":[0,1,2,3,4,5,6],"xaxis":"x","y":[83,93,102,96,90,143,144],"yaxis":"y","type":"scatter"},{"hovertemplate":"start_station_id=519<br>day_of_week=%{x}<br>num_trips=%{y}<extra></extra>","legendgroup":"519","line":{"color":"#B6E880","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"519","orientation":"v","showlegend":true,"x":[0,1,2,3,4,5,6],"xaxis":"x","y":[213,264,264,220,224,72,78],"yaxis":"y","type":"scatter"},{"hovertemplate":"start_station_id=523<br>day_of_week=%{x}<br>num_trips=%{y}<extra></extra>","legendgroup":"523","line":{"color":"#FF97FF","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"523","orientation":"v","showlegend":true,"x":[0,1,2,3,4,5,6],"xaxis":"x","y":[106,136,138,152,131,48,36],"yaxis":"y","type":"scatter"},{"hovertemplate":"start_station_id=3255<br>day_of_week=%{x}<br>num_trips=%{y}<extra></extra>","legendgroup":"3255","line":{"color":"#FECB52","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"3255","orientation":"v","showlegend":true,"x":[0,1,2,3,4,5,6],"xaxis":"x","y":[138,173,162,157,151,41,60],"yaxis":"y","type":"scatter"}],                         ...

# %%
px.histogram(df, x='hour', facet_col='dayofweek')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="9437aa5e-aa4e-4da7-ae1c-c7572e08ec9a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9437aa5e-aa4e-4da7-ae1c-c7572e08ec9a")) {                    Plotly.newPlot(                        "9437aa5e-aa4e-4da7-ae1c-c7572e08ec9a",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"dayofweek=Mon<br>hour=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[16,15,0,16,23,7,16,21,9,16,13,19,8,10,8,11,15,11,18,16,15,18,10,13,18,11,14,16,8,16,18,8,17,17,18,13,20,22,12,14,8,16,17,17,9,18,8,21,16,4,19,9,15,10,18,19,8,7,14,20,19,13,0,18,18,13,19,17,14,9,19,20,18,7,18,18,7,15,20,9,14,10,8,17,18,8,0,8,21,14,18,8,9,17,7,17,8,10,12,12,22,11,8,19,16,8,20,18,21,9,12,18,18,19,12,20,17,17,10,11,7,10,11,12,8,17,19,13,19,9,19,21,15,17,17,18,9,9,18,12,16,18,8,7,18,14,7,17,9,16,12,23,17,14,11,13
21,9,8,18,9,12,20,9,16,17,15,12,8,15,14,18,17,18,10,20,13,11,15,18,12,15,21,18,12,9,12,22,14,7,18,7,21,16,17,15,7,17,13,10,7,16,8,8,9,17,8,9,11,13,7,19,7,9,9,17,18,8,13,7,14,18,17,8,20,19,20,7,8,13,8,8,8,8,14,16,21,8,18,13,8,13,15,17,8,23,19,11,13,11,20,19,12,17,19,21,9,15,18,14,17,16,8,18,19,16,21,8,20,20,22,20,16,18,19,15,21,8,17,22,15,18,17,8,13,22,8,18,2,6,19,8,18,14,20,0,13,17,11,17,8,16,9,17,19,17,6,18,7,9,20,18,18,15,21,8,19,18,16,7,8,15,19,20,18,19,17,13,18,12,8,17,10,8,16,18,16,10,11,8,6,17,19,17,18,17,18,14,9,21,16,20,20,18,8,9,19,0,16,8,14,8,7,16,7,16,7,18,16,19,12,21,16,8,10,8,7,16,12,10,18,8,7,21,9,10,20,7,18,22,20,19,10,16,20,16,18,9,16,19,8,16,10,21,14,13,13,19,18,20,13,19,13,14,17,16,16,17,18,18,10,18,7,16,1 ...

# %%
df.head()
# Out:
#    Unnamed: 0  tripduration           starttime            stoptime  \
# 0           0          1877 2017-04-03 16:51:00 2017-04-03 17:22:00
# 1           1           314 2017-04-11 08:26:00 2017-04-11 08:31:00
# 2           2          2686 2017-04-15 16:12:00 2017-04-15 16:56:00
# 3           3          1494 2017-07-10 15:28:00 2017-07-10 15:53:00
# 4           4           606 2017-08-22 10:13:00 2017-08-22 10:23:00
#
#    start_station_id  start_station_name  start_station_latitude  \
# 0               498  Broadway & W 32 St               40.748549
# 1               533  Broadway & W 39 St               40.752996
# 2               430    York St & Jay St               40.701485
# 3              3474   6 Ave & Spring St               40.725256
# 4               432   E 7 St & Avenue A               40.726218
#
#    start_station_longitude  end_station_id         end_station_name  ...  \
# 0               -73.988084             382  University Pl & E 14 St  ...
# 1               -73.987216             402       Broadway & E 22 St  ...
# 2               -73.986569            3125            45 Rd & 11 St  ...
# 3               -74.004121             480         W 53 St & 10 Ave  ...
# 4               -73.983799             438      St Marks Pl & 1 Ave  ...
#
#    customer_plan  dayofweek   age num_trips  tripduration_min month  day  \
# 0            NaN        Mon   NaN         1         31.283333     4    3
# 1            NaN        Tue  25.0         1          5.233333     4   11
# 2            NaN        Sat  25.0         1         44.766667     4   15
# 3            NaN        Mon  45.0         1         24.900000     7   10
# 4            NaN        Tue  25.0         1         10.100000     8   22
#
#          date  hour  day_of_week
# 0  2017-04-03    16            0
# 1  2017-04-11     8            1
# 2  2017-04-15    16            5
# 3  2017-07-10    15            0
# 4  2017-08-22    10            1
#
# [5 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'tripduration', 'starttime', 'stoptime',
#        'start_station_id', 'start_station_name', 'start_station_latitude',
#        'start_station_longitude', 'end_station_id', 'end_station_name',
#        'end_station_latitude', 'end_station_longitude', 'bikeid', 'usertype',
#        'birth_year', 'gender', 'customer_plan', 'dayofweek', 'age',
#        'num_trips', 'tripduration_min', 'month', 'day', 'date', 'hour',
#        'day_of_week'],
#       dtype='object')

# %%
px.histogram(df, x='hour', facet_col='dayofweek', facet_row='usertype')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id
# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(12, 8))
fig = sns.heatmap(demogra_pivot, annot=True)

# %%
fig = plt.figure(figsize=(12, 8))
fig = sns.boxplot(data=df.query('gender in ["male", "female"]'),
                  x='age', y='tripduration_min',hue='gender')

# %%
fig = plt.figure(figsize=(12, 8))
query = '(gender in ["male", "female"]) & (tripduration_min <= 100) & (age <= 100)'
fig = sns.boxplot(data=df.query(query),
                  x='age', y='tripduration_min',hue='gender')

# %%
df.head()
# Out:
#    Unnamed: 0  tripduration           starttime            stoptime  \
# 0           0          1877 2017-04-03 16:51:00 2017-04-03 17:22:00
# 1           1           314 2017-04-11 08:26:00 2017-04-11 08:31:00
# 2           2          2686 2017-04-15 16:12:00 2017-04-15 16:56:00
# 3           3          1494 2017-07-10 15:28:00 2017-07-10 15:53:00
# 4           4           606 2017-08-22 10:13:00 2017-08-22 10:23:00
#
#    start_station_id  start_station_name  start_station_latitude  \
# 0               498  Broadway & W 32 St               40.748549
# 1               533  Broadway & W 39 St               40.752996
# 2               430    York St & Jay St               40.701485
# 3              3474   6 Ave & Spring St               40.725256
# 4               432   E 7 St & Avenue A               40.726218
#
#    start_station_longitude  end_station_id         end_station_name  ...  \
# 0               -73.988084             382  University Pl & E 14 St  ...
# 1               -73.987216             402       Broadway & E 22 St  ...
# 2               -73.986569            3125            45 Rd & 11 St  ...
# 3               -74.004121             480         W 53 St & 10 Ave  ...
# 4               -73.983799             438      St Marks Pl & 1 Ave  ...
#
#    customer_plan  dayofweek   age num_trips  tripduration_min month  day  \
# 0            NaN        Mon   NaN         1         31.283333     4    3
# 1            NaN        Tue  25.0         1          5.233333     4   11
# 2            NaN        Sat  25.0         1         44.766667     4   15
# 3            NaN        Mon  45.0         1         24.900000     7   10
# 4            NaN        Tue  25.0         1         10.100000     8   22
#
#          date  hour  day_of_week
# 0  2017-04-03    16            0
# 1  2017-04-11     8            1
# 2  2017-04-15    16            5
# 3  2017-07-10    15            0
# 4  2017-08-22    10            1
#
# [5 rows x 26 columns]

# %%
fig = px.density_mapbox(df.sample(30000).sort_values(by='hour'),
                        lat='start_station_latitude', lon='start_station_longitude',
                        z='num_trips', radius=5, mapbox_style='stamen-watercolor',
                        animation_frame='hour', width=800, height=600)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="11051b7a-717c-44af-b9a4-62ec06c7f8d1" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("11051b7a-717c-44af-b9a4-62ec06c7f8d1")) {                    Plotly.newPlot(                        "11051b7a-717c-44af-b9a4-62ec06c7f8d1",                        [{"coloraxis":"coloraxis","hovertemplate":"hour=0<br>num_trips=%{z}<br>start_station_latitude=%{lat}<br>start_station_longitude=%{lon}<extra></extra>","lat":[40.74444921,40.69512845,40.751551,40.75097711,40.76915505,40.71602118,40.69196035,40.7575699,40.6686273,40.71754834,40.734232,40.78948542,40.73291553,40.72217444,40.695065,40.72779126,40.76309387,40.75019995,40.73266,40.68753406,40.78275,40.7451677,40.74734825,40.74096374,40.7961535,40.76009437,40.740983,40.68691865,40.7361967,40.78339981,40.710451,40.74144387,40.75019995,40.72317958,40.7575699,40.77140426,40.